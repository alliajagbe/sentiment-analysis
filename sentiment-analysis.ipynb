# %%
import pandas as pd

# %%
# read the data
education = pd.read_excel('../data/Education Obstacle - opening.xlsx', header=None)
education.head()
# Out:
#                                                   0        1      2   \
# 0       Note: there are more sheets in this document      NaN    NaN
# 1  Each session is found on its own sheet below. ...      NaN    NaN
# 2                                               Date  Session  Voter
# 3                                         2023-06-19        1      1
# 4                                         2023-06-19        1      2
#
#                                                   3   \
# 0                                                NaN
# 1                                                NaN
# 2  If you want to change the world, throw a bette...
# 3                                                NaN
# 4                                                NaN
#
#                                   4    5                               6   \
# 0                                NaN  NaN                             NaN
# 1                                NaN  NaN                             NaN
# ...

# %% [markdown]
# # Data Cleaning

# %%
# deleting the header
education = education.iloc[1:]

# %%
education.head()
# Out:
#   Note: there are more sheets in this document Unnamed: 1 Unnamed: 2  \
# 1                                         Date    Session      Voter
# 2                                   2023-06-19          1          1
# 3                                   2023-06-19          1          2
# 4                                   2023-06-19          1          3
# 5                                   2023-06-19          1          4
#
#                                           Unnamed: 3  \
# 1  If you want to change the world, throw a bette...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#                           Unnamed: 4 Unnamed: 5  \
# 1  Welcome to the Obstacle Courses!:          :
# 2                                NaN        NaN
# 3                                NaN        NaN
# ...

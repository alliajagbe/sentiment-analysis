# %%
import pandas as pd
from functions import header_df, frequency_analysis, word_cloud

# %%
closing = pd.read_excel('../data/Closing Ceremonies.xlsx', header=None)
closing.head()
# Out:
#                                                   0        1      2   \
# 0       Note: there are more sheets in this document      NaN    NaN
# 1  Each session is found on its own sheet below. ...      NaN    NaN
# 2                                               Date  Session  Voter
# 3                                         2023-06-22        1      1
# 4                                         2023-06-22        1      2
#
#                                                   3   \
# 0                                                NaN
# 1                                                NaN
# 2  If you want to change the world, throw a bette...
# 3                                                NaN
# 4                                                NaN
#
#                                 4                                 5   \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2  Your contact details: Your name  Your contact details: Your email
# 3            nataliecrue@gmail.com             nataliecrue@gmail.com
# 4                              NaN                               NaN
#
#                                                   6   \
# 0                                                NaN
# 1                                                NaN
# 2  Which Networks Festival sessions did you parti...
# 3  Several Events. The obstacle courses were real...
# 4                                                NaN
#
#                                                   7   \
# 0                                                NaN
# 1                                                NaN
# 2  Can you share a testimonial - one sentence or ...
# 3                                                NaN
# 4                                                NaN
#
#                                                8   \
# 0                                             NaN
# 1                                             NaN
# 2  In what ways has the festival impacted you?: 1
# 3                                             NaN
# 4                                     encouraging
#
#                                                9   \
# 0                                             NaN
# 1                                             NaN
# 2  In what ways has the festival impacted you?: 2
# 3                                             NaN
# 4                     so much fun to hear stories
#
#                                                10  \
# 0                                             NaN
# 1                                             NaN
# 2  In what ways has the festival impacted you?: 3
# 3                                             NaN
# 4                                love this method
#
#                                                11  \
# 0                                             NaN
# 1                                             NaN
# 2  In what ways has the festival impacted you?: 4
# 3                                             NaN
# 4                         so many new connections
#
#                                                12  \
# 0                                             NaN
# 1                                             NaN
# 2  In what ways has the festival impacted you?: 5
# 3                                             NaN
# 4                                    common goals
#
#                                                   13  \
# 0                                                NaN
# 1                                                NaN
# 2     In what ways has the festival impacted you?: 6
# 3                                                NaN
# 4  love hearing about system changes - one small ...
#
#                                                   14  \
# 0                                                NaN
# 1                                                NaN
# 2     In what ways has the festival impacted you?: 7
# 3                                                NaN
# 4  Feel encouraged to speak up in the network I p...
#
#                                                   15  \
# 0                                                NaN
# 1                                                NaN
# 2  Can you share a concrete story of something th...
# 3                                                NaN
# 4  Not sure how I got connected to this conferenc...
#
#                                                   16  \
# 0                                                NaN
# 1                                                NaN
# 2  What network topics are you curious to explore...
# 3                                                NaN
# 4                                                NaN
#
#                                                   17
# 0                                                NaN
# 1                                                NaN
# 2  What might you be interested in engaging with?: 1
# 3                                                NaN
# 4                                                NaN

# %%
closing = header_df(closing)
closing.head()
# Out:
# 2        Date Session Voter  \
# 0  2023-06-22       1     1
# 1  2023-06-22       1     2
# 2  2023-06-22       1     3
# 3  2023-06-22       1     4
# 4  2023-06-22       1     5
#
# 2 If you want to change the world, throw a better party!:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 Your contact details: Your name Your contact details: Your email  \
# 0           nataliecrue@gmail.com            nataliecrue@gmail.com
# 1                             NaN                              NaN
# 2               emmanuelle@chiche               emchiche@gmail.com
# 3                             NaN                              NaN
# 4                       Luz@Avruj                lmavruj@gmail.com
#
# 2 Which Networks Festival sessions did you participate in?:  \
# 0  Several Events. The obstacle courses were real...
# 1                                                NaN
# 2                              Many! Loved them all!
# 3  Opening ceremonies and participatory facilitation
# 4                                      Only this one
#
# 2 Can you share a testimonial - one sentence or a quote of what the festival has meant to you?:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Beautiful way to engage with people from acros...
# 4                                                NaN
#
# 2     In what ways has the festival impacted you?: 1  \
# 0                                                NaN
# 1                                        encouraging
# 2                                                NaN
# 3  Some new ways to facilitate other virtual grou...
# 4                                                NaN
#
# 2 In what ways has the festival impacted you?: 2  \
# 0                                            NaN
# 1                    so much fun to hear stories
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# 2 In what ways has the festival impacted you?: 3  \
# 0                                            NaN
# 1                               love this method
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# 2 In what ways has the festival impacted you?: 4  \
# 0                                            NaN
# 1                        so many new connections
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# 2 In what ways has the festival impacted you?: 5  \
# 0                                            NaN
# 1                                   common goals
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# 2     In what ways has the festival impacted you?: 6  \
# 0                                                NaN
# 1  love hearing about system changes - one small ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2     In what ways has the festival impacted you?: 7  \
# 0                                                NaN
# 1  Feel encouraged to speak up in the network I p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 Can you share a concrete story of something that happened as a result of your participation?:  \
# 0                                                NaN
# 1  Not sure how I got connected to this conferenc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 What network topics are you curious to explore more deeply?: 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 What might you be interested in engaging with?: 1
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %% [markdown]
# # Renaming the Necessary Columns

# %%
closing = closing.rename(columns={'Your contact details: Your name': 'name'})
closing = closing.rename(columns={'Your contact details: Your email': 'email'})
closing = closing.rename(columns={'Which Networks Festival sessions did you participate in?:': 'sessions'})
closing = closing.rename(columns={'Can you share a testimonial - one sentence or a quote of what the festival has meant to you?:': 'testimonial'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 1': 'impact1'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 2': 'impact2'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 3': 'impact3'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 4': 'impact4'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 5': 'impact5'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 6': 'impact6'})
closing = closing.rename(columns={'In what ways has the festival impacted you?: 7': 'impact7'})
closing = closing.rename(columns={'Can you share a concrete story of something that happened as a result of your participation?:': 'story'})
closing.head()
# Out:
# 2        Date Session Voter  \
# 0  2023-06-22       1     1
# 1  2023-06-22       1     2
# 2  2023-06-22       1     3
# 3  2023-06-22       1     4
# 4  2023-06-22       1     5
#
# 2 If you want to change the world, throw a better party!:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2                   name                  email  \
# 0  nataliecrue@gmail.com  nataliecrue@gmail.com
# 1                    NaN                    NaN
# 2      emmanuelle@chiche     emchiche@gmail.com
# 3                    NaN                    NaN
# 4              Luz@Avruj      lmavruj@gmail.com
#
# 2                                           sessions  \
# 0  Several Events. The obstacle courses were real...
# 1                                                NaN
# 2                              Many! Loved them all!
# 3  Opening ceremonies and participatory facilitation
# 4                                      Only this one
#
# 2                                        testimonial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Beautiful way to engage with people from acros...
# 4                                                NaN
#
# 2                                            impact1  \
# 0                                                NaN
# 1                                        encouraging
# 2                                                NaN
# 3  Some new ways to facilitate other virtual grou...
# 4                                                NaN
#
# 2                      impact2           impact3                  impact4  \
# 0                          NaN               NaN                      NaN
# 1  so much fun to hear stories  love this method  so many new connections
# 2                          NaN               NaN                      NaN
# 3                          NaN               NaN                      NaN
# 4                          NaN               NaN                      NaN
#
# 2       impact5                                            impact6  \
# 0           NaN                                                NaN
# 1  common goals  love hearing about system changes - one small ...
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
# 2                                            impact7  \
# 0                                                NaN
# 1  Feel encouraged to speak up in the network I p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2                                              story  \
# 0                                                NaN
# 1  Not sure how I got connected to this conferenc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 What network topics are you curious to explore more deeply?: 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2 What might you be interested in engaging with?: 1
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %% [markdown]
# # Extracting Only the Necessary Columns

# %%
new_closing = closing[['name', 'email', 'sessions', 'testimonial', 'impact1', 'impact2', 'impact3', 'impact4', 'impact5', 'impact6', 'impact7', 'story']]
new_closing.head()
# Out:
# 2                   name                  email  \
# 0  nataliecrue@gmail.com  nataliecrue@gmail.com
# 1                    NaN                    NaN
# 2      emmanuelle@chiche     emchiche@gmail.com
# 3                    NaN                    NaN
# 4              Luz@Avruj      lmavruj@gmail.com
#
# 2                                           sessions  \
# 0  Several Events. The obstacle courses were real...
# 1                                                NaN
# 2                              Many! Loved them all!
# 3  Opening ceremonies and participatory facilitation
# 4                                      Only this one
#
# 2                                        testimonial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Beautiful way to engage with people from acros...
# 4                                                NaN
#
# 2                                            impact1  \
# 0                                                NaN
# 1                                        encouraging
# 2                                                NaN
# 3  Some new ways to facilitate other virtual grou...
# 4                                                NaN
#
# 2                      impact2           impact3                  impact4  \
# 0                          NaN               NaN                      NaN
# 1  so much fun to hear stories  love this method  so many new connections
# 2                          NaN               NaN                      NaN
# 3                          NaN               NaN                      NaN
# 4                          NaN               NaN                      NaN
#
# 2       impact5                                            impact6  \
# 0           NaN                                                NaN
# 1  common goals  love hearing about system changes - one small ...
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
#
# 2                                            impact7  \
# 0                                                NaN
# 1  Feel encouraged to speak up in the network I p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 2                                              story
# 0                                                NaN
# 1  Not sure how I got connected to this conferenc...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
len(new_closing)
# Out:
# 21

# %% [markdown]
# # Frequency Word Analysis

# %%
# removing nan values
sessions = new_closing.dropna(subset=['sessions'])

# %%
sessions = sessions['sessions']

# %%
sessions.head()
# Out:
# 0    Several Events. The obstacle courses were real...
# 2                                Many! Loved them all!
# 3    Opening ceremonies and participatory facilitation
# 4                                        Only this one
# 5                                             Workshop
# Name: sessions, dtype: object

# %%
# freq word analysis
sessions = pd.DataFrame(sessions, columns=['sessions'])
sessions_words = frequency_analysis(sessions, 'sessions')

# %%
sessions_words
# Out:
# ['several',
#  'events',
#  'obstacle',
#  'courses',
#  'really',
#  'coolmany',
#  'loved',
#  'opening',
#  'ceremonies',
#  'participatory',
#  'facilitationonly',
#  'oneworkshopregenerative',
#  'evaluation',
#  'making',
#  'case',
#  'networksthis',
#  'final',
#  'session',
#  'networkssystems',
#  'cultivating',
#  'impact',
#  'networks',
#  'network',
#  'ritualscommunity',
#  'mapping',
#  'closingplaying',
#  'fearfood',
#  'obstacle',
#  'systems',
#  'networks',
#  'opening',
#  'session',
#  'transformationopening',
#  'ceremony',
#  'climate',
#  'justice',
#  'obstacle',
#  'course',
#  'systems',
#  'practiceenlivening',
#  'communities',
#  'practice',
#  'compasseducation',
#  'obstacle',
#  'courserituals',
#  'carry',
#  'medicine',
#  'woman',
#  'favoritea',
#  'sessions',
#  'enjoyed',
#  'wish',
#  'done',
#  'moreeducational',
#  'sectoropening',
#  'closing',
#  'cermoniesbuilding',
#  'impact',
#  'network',
#  'playing',
#  'baddiesopening',
#  'funder',
#  's',
#  'pitch']

# %% [markdown]
# # Word Cloud Visualization for the Sessions

# %%
word_cloud('sessions', sessions_words)

# %%
# word cloud cleanup
removed = ['several','wish', 'carry', 'coolmany', 'playing', 's', 'making', 'done']
for x in removed:
    sessions_words.remove(x)

# %%
sessions_words = [word for phrase in sessions_words for word in phrase.split('playing')]
sessions_words = [word for phrase in sessions_words for word in phrase.split('only')]
sessions_words = [word for phrase in sessions_words for word in phrase.split('this')]
sessions_words = [word for phrase in sessions_words for word in phrase.split('workshop')]
sessions_words.append('workshop')
sessions_words = [word for phrase in sessions_words for word in phrase.split('building')]
sessions_words.append('building')
sessions_words = [word for phrase in sessions_words for word in phrase.split('systems')]
sessions_words.append('systems')
sessions_words = [word for phrase in sessions_words for word in phrase.split('opening')]
sessions_words.append('opening')
sessions_words = [word for phrase in sessions_words for word in phrase.split('rituals')]
sessions_words.append('rituals')
sessions_words = [word for phrase in sessions_words for word in phrase.split('educational')]
sessions_words.append('education')
sessions_words = [word for phrase in sessions_words for word in phrase.split('education')]
sessions_words.append('education')
sessions_words.remove('really')
sessions_words.remove('one')
sessions_words = [word for phrase in sessions_words for word in phrase.split('enlivening')]
sessions_words.append('enlivening')
sessions_words = [word for phrase in sessions_words for word in phrase.split('community')]
sessions_words.append('community')

# %%
sessions_words = list(filter(None, sessions_words))
sessions_words
# Out:
# ['events',
#  'obstacle',
#  'courses',
#  'loved',
#  'ceremonies',
#  'participatory',
#  'facilitation',
#  'regenerative',
#  'evaluation',
#  'case',
#  'networks',
#  'final',
#  'session',
#  'networks',
#  'cultivating',
#  'impact',
#  'networks',
#  'network',
#  'mapping',
#  'closing',
#  'fearfood',
#  'obstacle',
#  'networks',
#  'session',
#  'transformation',
#  'ceremony',
#  'climate',
#  'justice',
#  'obstacle',
#  'course',
#  'practice',
#  'communities',
#  'practice',
#  'compass',
#  'obstacle',
#  'course',
#  'medicine',
#  'woman',
#  'favoritea',
#  'sessions',
#  'enjoyed',
#  'more',
#  'sector',
#  'closing',
#  'cermonies',
#  'impact',
#  'network',
#  'baddies',
#  'funder',
#  'pitch',
#  'workshop',
#  'building',
#  'systems',
#  'opening',
#  'rituals',
#  'education',
#  'enlivening',
#  'community']

# %%
word_cloud('sessions', sessions_words)

# %% [markdown]
# # Sentiment Analysis for the Testimonials

# %%
testimonials = new_closing.dropna(subset=['testimonial'])
testimonials.head()
# Out:
# 2                   name                     email  \
# 3                    NaN                       NaN
# 5           Sarah@Davids  sarahdavidsngq@gmail.com
# 7     Carri@converge.net        Carri@converge.net
# 9                    NaN                       NaN
# 10  Juneholley@gmail.com      juneholley@gmail.com
#
# 2                                            sessions  \
# 3   Opening ceremonies and participatory facilitation
# 5                                            Workshop
# 7   This final session, networks-systems, cultivat...
# 9                                   Playing with Fear
# 10  Food Obstacle, systems and networks, opening s...
#
# 2                                         testimonial  \
# 3   Beautiful way to engage with people from acros...
# 5   Potential and possibility for change and trans...
# 7   Connecting with like-minded, vibrant, caring p...
# 9        Learning, sharing, experiences, interacting!
# 10  Met such wonderful people from all over the wo...
#
# 2                                             impact1  \
# 3   Some new ways to facilitate other virtual grou...
# 5   Meeting new people, learning and marketing of ...
# 7   It gave me a chance to experiment and co-creat...
# 9   The stories and experiences shared in the well...
# 10  How much fun we can have online - Fash as faci...
#
# 2                                             impact2 impact3 impact4 impact5  \
# 3                                                 NaN     NaN     NaN     NaN
# 5   intentional focus on raising awareness around ...     NaN     NaN     NaN
# 7                                                 NaN     NaN     NaN     NaN
# 9                                                 NaN     NaN     NaN     NaN
# 10  I was able to follow up with a couple of peopl...     NaN     NaN     NaN
#
# 2  impact6 impact7 story
# 3      NaN     NaN   NaN
# 5      NaN     NaN   NaN
# 7      NaN     NaN   NaN
# 9      NaN     NaN   NaN
# 10     NaN     NaN   NaN
